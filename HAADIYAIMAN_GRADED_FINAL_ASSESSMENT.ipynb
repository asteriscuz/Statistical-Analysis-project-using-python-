# %%
import pandas as pd

# %%
df=pd.read_csv('movie.csv')

# %%
df.head()
# Out:
#                                         title    year  color content_rating  \
# 0                                      Avatar  2009.0  Color          PG-13
# 1    Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                     Spectre  2015.0  Color          PG-13
# 3                       The Dark Knight Rises  2012.0  Color          PG-13
# 4  Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#    duration      director_name  director_fb           actor1  actor1_fb  \
# 0     178.0      James Cameron          0.0      CCH Pounder     1000.0
# 1     169.0     Gore Verbinski        563.0      Johnny Depp    40000.0
# 2     148.0         Sam Mendes          0.0  Christoph Waltz    11000.0
# 3     164.0  Christopher Nolan      22000.0        Tom Hardy    27000.0
# 4       NaN        Doug Walker        131.0      Doug Walker      131.0
#
#              actor2  ...  actor3_fb        gross  \
# ...

# %%
df.shape
# Out:
# (4916, 22)

# %%
## 16- how many movies are in hindi? how many hindi movies are there after the year 2000?

# %%
df.loc[df['language']=='Hindi'].shape[0]
# Out:
# 28

# %%
df.loc[(df['language']=='Hindi') & (df['year']>2000)].shape[0]
# Out:
# 25

# %%
## 17- group the movies by language and find out the avg budget of the country egypt

# %%
d1=df.groupby(['language','country']).head()
d1
# Out:
#                                          title    year            color  \
# 0                                       Avatar  2009.0            Color
# 1     Pirates of the Caribbean: At World's End  2007.0            Color
# 2                                      Spectre  2015.0            Color
# 3                        The Dark Knight Rises  2012.0            Color
# 5                                  John Carter  2012.0            Color
# ...                                        ...     ...              ...
# 4805                         The World Is Mine  2015.0            Color
# 4822                      The Brain That Sings  2013.0            Color
# 4895                      Stories of Our Lives  2014.0  Black and White
# 4900                                The Circle  2000.0            Color
# 4907                                    Cavite  2005.0            Color
#
#      content_rating  duration              director_name  director_fb  \
# ...

# %%
d1.loc[d1['country']=='Egypt','budget'].mean()
# Out:
# 1500000.0

# %%
## 18- how many movies are from 1970s and imbd scores greator than 8?

# %%
df.loc[(df['year'].between(1970,1979,inclusive=True)) & (df['imdb_score']>8)].shape[0]
# Out:
# /var/folders/bf/76rc9pvx4y95pxbrlkk63m5m0000gn/T/ipykernel_18918/3464721929.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df.loc[(df['year'].between(1970,1979,inclusive=True)) & (df['imdb_score']>8)].shape[0]
# 19

# %%
##  19 was not there in the options so i have chosen 2 in the quiz

# %%
## 19- how many movies rated R,PG13 or PG?

# %%
df.loc[(df['content_rating']=='R')+(df['content_rating']=='PG-13')+(df['content_rating']=='PG')].shape[0]
# Out:
# 4164

# %%
## 20- find out movies where actor1 is johhny depp and find out how many movies of his were directed by gore verbinski

# %%
df.loc[df['actor1']=='Johnny Depp'].shape[0]
# Out:
# 36

# %%
df.loc[(df['actor1']=='Johnny Depp') & (df['director_name']=='Gore Verbinski')].shape[0]
# Out:
# 5

# %%
## 21- display the movies with imbd score with highest to lowest to find the avg imbd score

# %%
d1=df.sort_values(by='imdb_score',ascending=False)
d1
# Out:
#                                title    year  color content_rating  duration  \
# 2725                Towering Inferno     NaN  Color            NaN      65.0
# 1920        The Shawshank Redemption  1994.0  Color              R     142.0
# 3402                   The Godfather  1972.0  Color              R     175.0
# 2779                         Dekalog     NaN  Color          TV-MA      55.0
# 4312            Kickboxer: Vengeance  2016.0    NaN            NaN      90.0
# ...                              ...     ...    ...            ...       ...
# 2266    Superbabies: Baby Geniuses 2  2004.0  Color             PG      88.0
# 2240                  Disaster Movie  2008.0  Color          PG-13      88.0
# 4498             The Helix... Loaded  2005.0  Color              R      97.0
# 1126                      Foodfight!  2012.0  Color             PG      91.0
# 2789  Justin Bieber: Never Say Never  2011.0  Color              G     115.0
#
# ...

# %%
d1.agg({'imdb_score':'mean'})
# Out:
# imdb_score    6.437429
# dtype: float64

# %%
## 22- how many movies with atleast one of the 3 actors with more than 10,000 fb likes

# %%
df.loc[(df['actor1_fb']>10000)+(df['actor2_fb']>10000)+(df['actor3_fb']>10000)].shape[0]
# Out:
# 1337

# %%
## 23- how many columns contain missing values?

# %%
df.isnull().sum()
# Out:
# title                0
# year               106
# color               19
# content_rating     300
# duration            15
# director_name      102
# director_fb        102
# actor1               7
# actor1_fb            7
# actor2              13
# actor2_fb           13
# actor3              23
# actor3_fb           23
# gross              862
# genres               0
# num_reviews         49
# num_voted_users      0
# plot_keywords      152
# language            12
# country              5
# budget             484
# imdb_score           0
# dtype: int64

# %%
## 24- select movies that are either rated PG13 or were made after 2010. Find out title of highest gross movie among them

# %%
df.loc[(df['content_rating']=='PG-13')+(df['year']>2010)].sort_values('gross',ascending=False).head(1)
# Out:
#     title    year  color content_rating  duration  director_name  director_fb  \
# 0  Avatar  2009.0  Color          PG-13     178.0  James Cameron          0.0
#
#         actor1  actor1_fb            actor2  ...  actor3_fb        gross  \
# 0  CCH Pounder     1000.0  Joel David Moore  ...      855.0  760505847.0
#
#                             genres  num_reviews num_voted_users  \
# 0  Action|Adventure|Fantasy|Sci-Fi        723.0          886204
#
#                             plot_keywords  language country       budget  \
# 0  avatar|future|marine|native|paraplegic   English     USA  237000000.0
#
#   imdb_score
# 0        7.9
#
# [1 rows x 22 columns]

# %%
## 25- how many movies are directed by steven spielberg? find out the highest budget of the movie directed by him

# %%
df.loc[(df['director_name']=='Steven Spielberg')].shape[0]
# Out:
# 26

# %%
df.loc[(df['director_name']=='Steven Spielberg')].sort_values('budget',ascending=False).head(1)
# Out:
#                                                 title    year  color  \
# 54  Indiana Jones and the Kingdom of the Crystal S...  2008.0  Color
#
#    content_rating  duration     director_name  director_fb         actor1  \
# 54          PG-13     122.0  Steven Spielberg      14000.0  Harrison Ford
#
#     actor1_fb        actor2  ...  actor3_fb        gross  \
# 54    11000.0  Ray Winstone  ...     1000.0  317011114.0
#
#                       genres  num_reviews num_voted_users  \
# 54  Action|Adventure|Fantasy        470.0          333847
#
#                                         plot_keywords  language country  \
# 54  cult figure|femme fatale|indiana jones|unsubti...   English     USA
#
#          budget imdb_score
# 54  185000000.0        6.2
#
# [1 rows x 22 columns]
